# %%
import pandas as pd 
import numpy as np 
import xgboost as xgb

from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
data = pd.read_csv('ligue_1.csv')

# required_columns = 
data
# Out:
#     Div        Date   Time    HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    F2  05/08/2023  14:00  St Etienne        Grenoble     0     1   A     0
# 1    F2  05/08/2023  18:00     Ajaccio           Rodez     1     1   D     1
# 2    F2  05/08/2023  18:00      Amiens  Quevilly Rouen     1     0   H     0
# 3    F2  05/08/2023  18:00      Annecy        Guingamp     1     4   A     1
# 4    F2  05/08/2023  18:00  Concarneau          Bastia     0     0   D     0
# ..   ..         ...    ...         ...             ...   ...   ...  ..   ...
# 185  F2  19/12/2023  19:45   Dunkerque        Bordeaux     0     2   A     0
# 186  F2  19/12/2023  19:45       Laval         Auxerre     1     3   A     1
# 187  F2  19/12/2023  19:45    Paris FC  Quevilly Rouen     2     2   D     1
# 188  F2  19/12/2023  19:45      Pau FC          Troyes     1     1   D     0
# 189  F2  19/12/2023  19:45  St Etienne          Bastia     3     2   H     2
#
# ...

# %%
for column in data.columns:
    print(column)
# Out:
# Div
# Date
# Time
# HomeTeam
# AwayTeam
# FTHG
# FTAG
# FTR
# HTHG
# HTAG
# HTR
# HS
# AS
# HST
# AST
# HF
# AF
# HC
# AC
# HY
# AY
# HR
# AR
# B365H
# B365D
# B365A
# BWH
# BWD
# BWA
# IWH
# IWD
# IWA
# PSH
# PSD
# PSA
# WHH
# WHD
# WHA
# VCH
# VCD
# VCA
# MaxH
# MaxD
# MaxA
# AvgH
# AvgD
# AvgA
# B365>2.5
# B365<2.5
# P>2.5
# P<2.5
# Max>2.5
# Max<2.5
# Avg>2.5
# Avg<2.5
# AHh
# B365AHH
# B365AHA
# PAHH
# PAHA
# MaxAHH
# MaxAHA
# AvgAHH
# AvgAHA
# B365CH
# B365CD
# B365CA
# BWCH
# BWCD
# BWCA
# IWCH
# IWCD
# IWCA
# PSCH
# PSCD
# PSCA
# WHCH
# WHCD
# WHCA
# VCCH
# VCCD
# VCCA
# MaxCH
# MaxCD
# MaxCA
# AvgCH
# AvgCD
# AvgCA
# B365C>2.5
# B365C<2.5
# PC>2.5
# PC<2.5
# MaxC>2.5
# MaxC<2.5
# AvgC>2.5
# AvgC<2.5
# AHCh
# B365CAHH
# B365CAHA
# PCAHH
# PCAHA
# MaxCAHH
# MaxCAHA
# AvgCAHH
# AvgCAHA
